# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# این برنامه با استفاده از شبکه عصبی یاد می‌گیرد که مصرف سوخت یک ماشین (MPG) را از روی مشخصات آن مثل وزن، تعداد سیلندر، قدرت موتور و سال ساخت پیش‌بینی کند.
#
# برای این کار از کتابخانه‌های یادگیری ماشین مثل TensorFlow و Keras و از دیتاست معروف Auto MPG استفاده شده است.
#
# ---

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
#
# ## مرحله ۱: وارد کردن ابزارها
#
# در ابتدای کد، چند کتابخانه وارد می‌شوند:
#
# pandas → برای کار با داده‌ها
#
# matplotlib و seaborn → برای رسم نمودار
#
# tensorflow و keras → برای ساخت شبکه عصبی
#
# این‌ها ابزارهایی هستند که برنامه برای تحلیل داده و یادگیری استفاده می‌کند.

# %%
import pathlib #provides a readable and easier way to build paths
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from __future__ import absolute_import, division, print_function, unicode_literals

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
#
# ## مرحله ۲: دریافت داده‌ها
#
# در این قسمت داده‌های مربوط به ماشین‌ها از اینترنت دانلود می‌شوند.

# %%
dataset_path = keras.utils.get_file("auto-mpg.data","https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data")
dataset_path
# Out:
# 'C:\\Users\\ali_a\\.keras\\datasets\\auto-mpg.data'

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# - هر سطر = یک ماشین
# - هر ستون = یک ویژگی ماشین مثل:
# - تعداد سیلندر
# - وزن
# - قدرت موتور
# - سال ساخت
# - کشور سازنده
# - و مهم‌تر از همه → MPG (مصرف سوخت)
#
# هدف مدل اینه که MPG رو پیش‌بینی کنه.

# %%
column_names = ['MPG', 'Cylinders', 'Displacement', 'Hoursepower','Weight','Acceleration','Model Year','Origin']
raw_dataset = pd.read_csv(dataset_path, names = column_names, na_values="?", comment='\t', sep=" ", skipinitialspace= True)
dataset = raw_dataset.copy()
dataset
# Out:
#       MPG  Cylinders  Displacement  Hoursepower  Weight  Acceleration  \
# 0    18.0          8         307.0        130.0  3504.0          12.0
# 1    15.0          8         350.0        165.0  3693.0          11.5
# 2    18.0          8         318.0        150.0  3436.0          11.0
# 3    16.0          8         304.0        150.0  3433.0          12.0
# 4    17.0          8         302.0        140.0  3449.0          10.5
# ..    ...        ...           ...          ...     ...           ...
# 393  27.0          4         140.0         86.0  2790.0          15.6
# 394  44.0          4          97.0         52.0  2130.0          24.6
# 395  32.0          4         135.0         84.0  2295.0          11.6
# 396  28.0          4         120.0         79.0  2625.0          18.6
# 397  31.0          4         119.0         82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 2️⃣ پاک‌سازی داده‌ها
# ۶ تا مقدار خالی داشت → حذف شدن.

# %%
# We had around 6 NA values in our data, and we are dropping NA values
dataset=dataset.dropna()
dataset
# Out:
#       MPG  Cylinders  Displacement  Hoursepower  Weight  Acceleration  \
# 0    18.0          8         307.0        130.0  3504.0          12.0
# 1    15.0          8         350.0        165.0  3693.0          11.5
# 2    18.0          8         318.0        150.0  3436.0          11.0
# 3    16.0          8         304.0        150.0  3433.0          12.0
# 4    17.0          8         302.0        140.0  3449.0          10.5
# ..    ...        ...           ...          ...     ...           ...
# 393  27.0          4         140.0         86.0  2790.0          15.6
# 394  44.0          4          97.0         52.0  2130.0          24.6
# 395  32.0          4         135.0         84.0  2295.0          11.6
# 396  28.0          4         120.0         79.0  2625.0          18.6
# 397  31.0          4         119.0         82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# ...

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ستون Origin که عدد 1 و 2 و 3 بود، تبدیل شد به سه ستون جدا
# به این کار میگن One Hot Encoding
# چون کشور یه مقدار عددی واقعی نیست، یه دسته‌بندیه.

# %%
# 'Origin' colunm is categorical so creating one hot encoding
origin = dataset.pop('Origin')
dataset['USA'] = (origin == 1)*1.0
dataset['Europe'] = (origin == 2)*1.0
dataset['Japan'] = (origin == 3)*1.0
dataset.tail()
# Out:
#       MPG  Cylinders  Displacement  Hoursepower  Weight  Acceleration  \
# 393  27.0          4         140.0         86.0  2790.0          15.6
# 394  44.0          4          97.0         52.0  2130.0          24.6
# 395  32.0          4         135.0         84.0  2295.0          11.6
# 396  28.0          4         120.0         79.0  2625.0          18.6
# 397  31.0          4         119.0         82.0  2720.0          19.4
#
#      Model Year  USA  Europe  Japan
# 393          82  1.0     0.0    0.0
# 394          82  0.0     1.0    0.0
# 395          82  1.0     0.0    0.0
# 396          82  1.0     0.0    0.0
# 397          82  1.0     0.0    0.0

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 3️⃣ تقسیم داده به آموزش و تست
#
#
# ۸۰٪ داده برای آموزش
#
# ۲۰٪ برای تست
#
# خیلی مهمه چون مدل باید روی داده‌ای که ندیده امتحان بشه.

# %%
train_dataset = dataset.sample(frac=0.8,random_state=0) 
test_dataset = dataset.drop(train_dataset.index)

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>

# %%
#Multivariate analysis
sns.pairplot(train_dataset[["MPG", "Cylinders", "Displacement", "Weight"]], diag_kind="kde")

# %%
train_stats = train_dataset.describe()
train_stats
# Out:
#               MPG   Cylinders  Displacement  Hoursepower       Weight  \
# count  314.000000  314.000000    314.000000   314.000000   314.000000
# mean    23.310510    5.477707    195.318471   104.869427  2990.251592
# std      7.728652    1.699788    104.331589    38.096214   843.898596
# min     10.000000    3.000000     68.000000    46.000000  1649.000000
# 25%     17.000000    4.000000    105.500000    76.250000  2256.500000
# 50%     22.000000    4.000000    151.000000    94.500000  2822.500000
# 75%     28.950000    8.000000    265.750000   128.000000  3608.000000
# max     46.600000    8.000000    455.000000   225.000000  5140.000000
#
#        Acceleration  Model Year         USA      Europe       Japan
# count    314.000000  314.000000  314.000000  314.000000  314.000000
# mean      15.559236   75.898089    0.624204    0.178344    0.197452
# std        2.789230    3.675642    0.485101    0.383413    0.398712
# ...

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 4️⃣ جدا کردن برچسب (Label)
#
# ما می‌خوایم MPG رو پیش‌بینی کنیم
# پس MPG رو جدا می‌کنیم از بقیه ستون‌ها.

# %%
train_stats.pop("MPG")
# Out:
# count    314.000000
# mean      23.310510
# std        7.728652
# min       10.000000
# 25%       17.000000
# 50%       22.000000
# 75%       28.950000
# max       46.600000
# Name: MPG, dtype: float64

# %%
train_stats= train_stats.transpose()

# %%
train_dataset.head()
# Out:
#       MPG  Cylinders  Displacement  Hoursepower  Weight  Acceleration  \
# 146  28.0          4          90.0         75.0  2125.0          14.5
# 282  22.3          4         140.0         88.0  2890.0          17.3
# 69   12.0          8         350.0        160.0  4456.0          13.5
# 378  38.0          4         105.0         63.0  2125.0          14.7
# 331  33.8          4          97.0         67.0  2145.0          18.0
#
#      Model Year  USA  Europe  Japan
# 146          74  1.0     0.0    0.0
# 282          79  1.0     0.0    0.0
# 69           72  1.0     0.0    0.0
# 378          82  1.0     0.0    0.0
# 331          80  0.0     0.0    1.0

# %%
test_dataset.head()
# Out:
#      MPG  Cylinders  Displacement  Hoursepower  Weight  Acceleration  \
# 9   15.0          8         390.0        190.0  3850.0           8.5
# 25  10.0          8         360.0        215.0  4615.0          14.0
# 28   9.0          8         304.0        193.0  4732.0          18.5
# 31  25.0          4         113.0         95.0  2228.0          14.0
# 33  19.0          6         232.0        100.0  2634.0          13.0
#
#     Model Year  USA  Europe  Japan
# 9           70  1.0     0.0    0.0
# 25          70  1.0     0.0    0.0
# 28          70  1.0     0.0    0.0
# 31          71  0.0     0.0    1.0
# 33          71  1.0     0.0    0.0

# %%
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')
train_labels.head()
# Out:
# 146    28.0
# 282    22.3
# 69     12.0
# 378    38.0
# 331    33.8
# Name: MPG, dtype: float64

# %%
test_labels.head()
# Out:
# 9     15.0
# 25    10.0
# 28     9.0
# 31    25.0
# 33    19.0
# Name: MPG, dtype: float64

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 5️⃣ نرمال‌سازی (Standardization)
# چون:
#
# - وزن مثلا 3000 هست
# - سیلندر مثلا 4 هست
#
# اگر نرمال نکنیم مدل گیج میشه.
#
# پس همه رو میاریم تقریباً در بازه مشابه.

# %%
def normalization(x):
  return (x-train_stats['mean'])/ train_stats['std']

# %%
normed_train_data = normalization(train_dataset)
normed_test_data = normalization(test_dataset)

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 6️⃣ ساخت مدل شبکه عصبی
#
# مدل شامل:
#
# - لایه اول → 64 نورون
# - لایه دوم → 64 نورون
# - لایه خروجی → 1 عدد (MPG)
#
# این یعنی یه شبکه عصبی ساده برای رگرسیون.

# %%
# Method to build model 
def build_model():
  model = keras.Sequential([
    layers.Dense(64, activation=tf.nn.relu, input_shape=[len(train_dataset.keys())]),
    layers.Dense(64, activation=tf.nn.relu),
    layers.Dense(1)
  ])
  optimizer = tf.keras.optimizers.RMSprop(0.001)
 
  model.compile(loss='mean_squared_error',
                optimizer=optimizer,
                metrics=['mean_absolute_error', 'mean_squared_error'])
  return model

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>Optimizer:
#
# RMSprop
#
#
# Loss:
#
# mean_squared_error
#
#
# چون مسئله ما رگرسیون هست (عدد پیش‌بینی می‌کنیم).

# %%
model = build_model()
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,865 (19.00 KB)
#  Trainable params: 4,865 (19.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
example_batch = normed_train_data[:10]
example_batch
# Out:
#      Cylinders  Displacement  Hoursepower    Weight  Acceleration  Model Year  \
# 146  -0.869348     -1.009459    -0.784052 -1.025303     -0.379759   -0.516397
# 282  -0.869348     -0.530218    -0.442811 -0.118796      0.624102    0.843910
# 69    1.483887      1.482595     1.447140  1.736877     -0.738281   -1.060519
# 378  -0.869348     -0.865687    -1.099044 -1.025303     -0.308055    1.660094
# 331  -0.869348     -0.942365    -0.994047 -1.001603      0.875068    1.115971
# 257   0.307270      0.351586    -0.390312  0.260397      0.588250    0.571849
# 310  -0.869348     -1.019044    -1.177792 -1.211344      1.161885    1.115971
# 328  -0.869348     -0.472709    -0.994047  0.307796      2.237451    1.115971
# 125   0.307270      0.025702    -0.259066  0.132419      0.337285   -0.516397
# 108  -0.869348     -0.942365    -0.442811 -0.842816      1.233589   -0.788458
#
#           USA    Europe     Japan
# 146  0.774676 -0.465148 -0.495225
# 282  0.774676 -0.465148 -0.495225
# ...

# %%
# predict on example batch
example_result = model.predict(example_batch)
example_result
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# array([[-0.00758683],
#        [-0.19696012],
#        [-0.7090527 ],
#        [-0.14609373],
#        [-0.10990959],
#        [ 0.02404249],
#        [-0.08969651],
#        [-0.57197654],
#        [-0.0636479 ],
#        [ 0.14186825]], dtype=float32)

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>

# %%
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100  == 0: print('')
    print('.', end='')
#Number of epochs
EPOCHS = 1000

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 7️⃣ آموزش مدل
#
#
# مدل 1000 بار (epoch) داده‌ها رو می‌بینه و یاد می‌گیره.
#
# بعد نمودار خطا رسم میشه:
#
# - خطای آموزش
# - خطای اعتبارسنجی
#
# اگر این دو از هم خیلی فاصله بگیرند → overfitting

# %%
# train model
history = model.fit(
    normed_train_data, train_labels,
    epochs = EPOCHS, validation_split = 0.2, verbose = 0,
    callbacks=[PrintDot()]
)
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ...

# %%
# lets check loss, mean absolute error, mean square error, val loss, val mean squared error and val mean absolute error
hist = pd.DataFrame(history.history)
hist['epoch']= history.epoch
hist.tail()
# Out:
#          loss  mean_absolute_error  ...  val_mean_squared_error  epoch
# 995  2.908102             1.082935  ...                9.345091    995
# 996  2.942568             1.101065  ...                9.591268    996
# 997  2.870915             1.064631  ...                9.193254    997
# 998  2.814770             1.067690  ...                9.312841    998
# 999  2.965707             1.113947  ...                9.676250    999
#
# [5 rows x 7 columns]

# %%
def plot_history(history):
  hist = pd.DataFrame(history.history)
  hist['epoch']= history.epoch
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error [MPG]')
  plt.plot(hist['epoch'], hist['mean_absolute_error'], label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_absolute_error'], label='Val Error')
  plt.ylim([0,5])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Square Error [$MPG^2$]')
  plt.plot(hist['epoch'], hist['mean_squared_error'], label='Train Error')
  plt.plot(hist['epoch'], hist['val_mean_squared_error'], label='Val Error')
  plt.ylim([0,20])
  plt.legend()
  plt.show()

# %%
#plot train and validation loss
plot_history(history)

# %%
model = build_model()
early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(normed_train_data, train_labels, epochs=EPOCHS, validation_split=0.2, verbose=0, callbacks=[early_stop, PrintDot()])
plot_history(history)
# Out:
# ...............................................................................

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 9️⃣ ارزیابی مدل
#
# MAE یعنی:
#
# میانگین خطای پیش‌بینی چقدر بوده؟
#
# مثلاً اگر بنویسه:
# ```mathematica
# Testing dataset Mean Abs Error: 2.3 MPG
# ```
# یعنی مدل به طور متوسط ۲.۳ واحد اشتباه کرده.
#
# که برای این دیتاست خوبه 👍

# %%
loss, mae,mse  = model.evaluate(normed_test_data, test_labels, verbose=0)
print("Testing dataset Mean Abs Error (MAE): {:5.2f} MPG".format(mae))
# Out:
# Testing dataset Mean Abs Error (MAE):  1.85 MPG

# %%
test_predictions = model.predict(normed_test_data).flatten()

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 🔟 رسم نمودار پیش‌بینی
#
# اگر مدل خوب باشه، نقطه‌ها نزدیک خط صاف 45 درجه قرار می‌گیرند.

# %%
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0, plt.xlim()[1]])
plt.ylim([0, plt.ylim()[1]])
_= plt.plot([-100,100], [-100, 100])
plt.show()

# %%
error = test_predictions - test_labels
plt.hist(error, bins=25)
plt.xlabel("Prediction Error [MPG]")
_=plt.ylabel("Count")
plt.show()

# %% [markdown]
# <div dir="rtl" lang="fa" style="direction: rtl; text-align: right;
#      font-family: 'Vazirmatn', 'IRANSans', 'Tahoma', system-ui, sans-serif;
#      line-height: 1.85;
#      font-size: 1.05em;
#      max-width: 920px;
#      margin: 0 auto;
#      padding: 0 3em 0em 0em;
#      box-sizing: border-box;">
#
# <!-- استایل‌های اضافی برای تمایز عنوان‌ها از بدنه -->
# <style>
#   h1, h2, h3, h4, h5, h6 {
#     margin-right: 0.4em;          /* عنوان‌ها کمتر از راست فاصله دارند → راست‌تر */
#     padding-right: 0;
#     border-right: 3px solid #1976d2;   /* خط رنگی سمت راست عنوان برای زیبایی */
#     padding-right: 0.6em;
#   }
#
#   p, li, blockquote {
#     margin-right: 1.2em;          /* بدنه متن بیشتر از راست فاصله دارد */
#     text-indent: 0;
#   }
#
#   ul, ol {
#     padding-right: 1.5em;         /* لیست‌ها هم کمی داخل‌تر */
#     margin-right: 0.8em;
#   }
#
#   code, pre {
#     direction: ltr;
#     text-align: left;
#     font-family: 'Fira Code', 'Courier New', monospace;
#   }
# </style>
# ## 1️⃣1️⃣ ذخیره مدل
#
# مدل ذخیره میشه تا بعداً دوباره استفاده بشه.

# %%
model.save('myfirstmodel.h5')

# %%
from keras.models import load_model
newmodel = tf.keras.models.load_model('myfirstmodel.h5')

# %%
test_predictions = model.predict(normed_test_data).flatten()
